# %%
#データ操作に着目してpandasの基本操作をまとめます
import pandas as pd

# %%
#weather.csvの読み込み

# %%
df = pd.read_csv("weather.csv")
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
#読み込んだデータの確認
#先頭10行
#末尾10行

# %%
head10 = df.head(10)
head10
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# ...

# %%
tail10 = df.tail(10)
tail10
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 356      3.4     15.0       0.8          4.8      11.7           S
# 357      3.2     18.0       0.0          7.4      12.2         SSE
# 358      0.9     20.7       0.0          5.4       8.4         NNW
# 359      3.3     25.5       0.0          5.2      10.8           N
# 360      7.9     26.1       0.0          6.8       3.5         NNW
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 356           70.0          S          S          35.0  ...           24
# 357           48.0        SSE          S          26.0  ...           25
# ...

# %%
#不要な行・列の削除=必要な特定行・列の抽出

# %%
df.columns #一旦カラムを全表示させてみる
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
#仮に先頭3列と末尾3列を削除してみる。上記から特定項目を消すだけ
#というより必要な項目を残すとも言える
df[['Evaporation', 
    'Sunshine',
    'WindGustDir', 
    'WindGustSpeed', 
    'WindDir9am', 
    'WindDir3pm',
    'WindSpeed9am', 
    'WindSpeed3pm', 
    'Humidity9am', 
    'Humidity3pm',
    'Pressure9am', 
    'Pressure3pm', 
    'Cloud9am', 
    'Cloud3pm', 
    'Temp9am',
    'Temp3pm']]
# Out:
#      Evaporation  Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            3.4       6.3          NW           30.0         SW         NW
# 1            4.4       9.7         ENE           39.0          E          W
# 2            5.8       3.3          NW           85.0          N        NNE
# 3            7.2       9.1          NW           54.0        WNW          W
# 4            5.6      10.6         SSE           50.0        SSE        ESE
# ..           ...       ...         ...            ...        ...        ...
# 361          7.6      12.1         NNW           76.0        SSE         NW
# 362         11.6      12.7           N           48.0        NNW        NNW
# 363          8.4       5.3         ESE           43.0        ENE        ENE
# 364          5.0       7.1          NW           46.0        SSW        WNW
# 365          6.0      12.6          NW           78.0         NW        WNW
#
# ...

# %%
#データ型、サイズ、列名、行名を確認

# %%
#データ型
df.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
#サイズ
df.shape
# Out:
# (366, 22)

# %%
#列名
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
#行名
df.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
#任意の要素を取得する

# %%
#5～10行目、3～6列目の要素を取得
df.iloc[4:10, 2:6]
# Out:
#    Rainfall  Evaporation  Sunshine WindGustDir
# 4       2.8          5.6      10.6         SSE
# 5       0.0          5.8       8.2          SE
# 6       0.2          4.2       8.4          SE
# 7       0.0          5.6       4.6           E
# 8       0.0          4.0       4.1           S
# 9      16.2          5.4       7.7           E

# %%
#people.csvを読み込み、df_peopleと定義

# %%
df_people = pd.read_csv("people.csv")
df_people
#なんやこのデータセット
# Out:
#    ulke  boy  kilo   yas cinsiyet
# 0    tr  130    30  10.0        e
# 1    tr  125    36  11.0        e
# 2    tr  135    34  10.0        k
# 3    tr  133    30   9.0        k
# 4    tr  129    38  12.0        e
# 5    tr  180    90  30.0        e
# 6    tr  190    80  25.0        e
# 7    tr  175    90  35.0        e
# 8    tr  177    60  22.0        k
# 9    us  185   105  33.0        e
# 10   us  165    55   NaN        k
# 11   us  155    50  44.0        k
# 12   us  160    58  39.0        k
# 13   us  162    59   NaN        k
# 14   us  167    62  55.0        k
# 15   fr  174    70  47.0        e
# 16   fr  193    90  23.0        e
# 17   fr  187    80  27.0        e
# 18   fr  183    88  28.0        e
# 19   fr  159    40  29.0        k
# 20   fr  164    66  32.0        k
# 21   fr  166    56  42.0        k

# %%
#df_peopleから、ulke = us

# %%
df_people[df_people["ulke"] == "us"]
# Out:
#    ulke  boy  kilo   yas cinsiyet
# 9    us  185   105  33.0        e
# 10   us  165    55   NaN        k
# 11   us  155    50  44.0        k
# 12   us  160    58  39.0        k
# 13   us  162    59   NaN        k
# 14   us  167    62  55.0        k

# %%
df_people.query("ulke == 'us'")
# Out:
#    ulke  boy  kilo   yas cinsiyet
# 9    us  185   105  33.0        e
# 10   us  165    55   NaN        k
# 11   us  155    50  44.0        k
# 12   us  160    58  39.0        k
# 13   us  162    59   NaN        k
# 14   us  167    62  55.0        k

# %%
#boy > 130を抽出

# %%
df_people[df_people["boy"] > 130]
# Out:
#    ulke  boy  kilo   yas cinsiyet
# 2    tr  135    34  10.0        k
# 3    tr  133    30   9.0        k
# 5    tr  180    90  30.0        e
# 6    tr  190    80  25.0        e
# 7    tr  175    90  35.0        e
# 8    tr  177    60  22.0        k
# 9    us  185   105  33.0        e
# 10   us  165    55   NaN        k
# 11   us  155    50  44.0        k
# 12   us  160    58  39.0        k
# 13   us  162    59   NaN        k
# 14   us  167    62  55.0        k
# 15   fr  174    70  47.0        e
# 16   fr  193    90  23.0        e
# 17   fr  187    80  27.0        e
# 18   fr  183    88  28.0        e
# 19   fr  159    40  29.0        k
# 20   fr  164    66  32.0        k
# 21   fr  166    56  42.0        k

# %%
df_people.query("boy > 130")
# Out:
#    ulke  boy  kilo   yas cinsiyet
# 2    tr  135    34  10.0        k
# 3    tr  133    30   9.0        k
# 5    tr  180    90  30.0        e
# 6    tr  190    80  25.0        e
# 7    tr  175    90  35.0        e
# 8    tr  177    60  22.0        k
# 9    us  185   105  33.0        e
# 10   us  165    55   NaN        k
# 11   us  155    50  44.0        k
# 12   us  160    58  39.0        k
# 13   us  162    59   NaN        k
# 14   us  167    62  55.0        k
# 15   fr  174    70  47.0        e
# 16   fr  193    90  23.0        e
# 17   fr  187    80  27.0        e
# 18   fr  183    88  28.0        e
# 19   fr  159    40  29.0        k
# 20   fr  164    66  32.0        k
# 21   fr  166    56  42.0        k

# %%
#150 > boy >130 の抽出

# %%
df_people[(df_people["boy"] < 150) & (df_people["boy"] > 130)]
# Out:
#   ulke  boy  kilo   yas cinsiyet
# 2   tr  135    34  10.0        k
# 3   tr  133    30   9.0        k

# %%
#df_peopleのユニークな値(固有値)の抽出

# %%
#.uniqueメソッドを使用するが、このメソッドはSeries型にのみ適用⇒カラム一つずつを指定してやる
df_people["ulke"].unique()
# Out:
# array(['tr', 'us', 'fr'], dtype=object)

# %%
df_people["boy"].unique()
# Out:
# array([130, 125, 135, 133, 129, 180, 190, 175, 177, 185, 165, 155, 160,
#        162, 167, 174, 193, 187, 183, 159, 164, 166], dtype=int64)

# %%
#df_peopleのulke列に対し、重複のある値のある行を削除したdfを取得

# %%
#.drop_duplicatesを使用する
df_people.drop_duplicates(subset="ulke")
#subset = None の場合は全カラムで全一致した場合のみ重複とみなす
# Out:
#    ulke  boy  kilo   yas cinsiyet
# 0    tr  130    30  10.0        e
# 9    us  185   105  33.0        e
# 15   fr  174    70  47.0        e

# %%
#カラム名を変更　ulkeを国籍に変更

# %%
df_people.columns
# Out:
# Index(['ulke', 'boy', 'kilo', 'yas', 'cinsiyet'], dtype='object')

# %%
df_people.columns = ['国籍', 'boy', 'kilo', 'yas', 'cinsiyet']
df_people
# Out:
#     国籍  boy  kilo   yas cinsiyet
# 0   tr  130    30  10.0        e
# 1   tr  125    36  11.0        e
# 2   tr  135    34  10.0        k
# 3   tr  133    30   9.0        k
# 4   tr  129    38  12.0        e
# 5   tr  180    90  30.0        e
# 6   tr  190    80  25.0        e
# 7   tr  175    90  35.0        e
# 8   tr  177    60  22.0        k
# 9   us  185   105  33.0        e
# 10  us  165    55   NaN        k
# 11  us  155    50  44.0        k
# 12  us  160    58  39.0        k
# 13  us  162    59   NaN        k
# 14  us  167    62  55.0        k
# 15  fr  174    70  47.0        e
# 16  fr  193    90  23.0        e
# 17  fr  187    80  27.0        e
# 18  fr  183    88  28.0        e
# 19  fr  159    40  29.0        k
# 20  fr  164    66  32.0        k
# 21  fr  166    56  42.0        k

# %%
df_people = df_people.rename(columns={"boy":"男の子"})
df_people
# Out:
#     国籍  男の子  kilo   yas cinsiyet
# 0   tr  130    30  10.0        e
# 1   tr  125    36  11.0        e
# 2   tr  135    34  10.0        k
# 3   tr  133    30   9.0        k
# 4   tr  129    38  12.0        e
# 5   tr  180    90  30.0        e
# 6   tr  190    80  25.0        e
# 7   tr  175    90  35.0        e
# 8   tr  177    60  22.0        k
# 9   us  185   105  33.0        e
# 10  us  165    55   NaN        k
# 11  us  155    50  44.0        k
# 12  us  160    58  39.0        k
# 13  us  162    59   NaN        k
# 14  us  167    62  55.0        k
# 15  fr  174    70  47.0        e
# 16  fr  193    90  23.0        e
# 17  fr  187    80  27.0        e
# 18  fr  183    88  28.0        e
# 19  fr  159    40  29.0        k
# 20  fr  164    66  32.0        k
# 21  fr  166    56  42.0        k

# %%
#dfの並び替え　男の子を昇順に直す

# %%
df_people.sort_values("男の子")
# Out:
#     国籍  男の子  kilo   yas cinsiyet
# 1   tr  125    36  11.0        e
# 4   tr  129    38  12.0        e
# 0   tr  130    30  10.0        e
# 3   tr  133    30   9.0        k
# 2   tr  135    34  10.0        k
# 11  us  155    50  44.0        k
# 19  fr  159    40  29.0        k
# 12  us  160    58  39.0        k
# 13  us  162    59   NaN        k
# 20  fr  164    66  32.0        k
# 10  us  165    55   NaN        k
# 21  fr  166    56  42.0        k
# 14  us  167    62  55.0        k
# 15  fr  174    70  47.0        e
# 7   tr  175    90  35.0        e
# 8   tr  177    60  22.0        k
# 5   tr  180    90  30.0        e
# 18  fr  183    88  28.0        e
# 9   us  185   105  33.0        e
# 17  fr  187    80  27.0        e
# 6   tr  190    80  25.0        e
# 16  fr  193    90  23.0        e

# %%
#降順だと
df_people.sort_values("男の子", ascending=False)
# Out:
#     国籍  男の子  kilo   yas cinsiyet
# 16  fr  193    90  23.0        e
# 6   tr  190    80  25.0        e
# 17  fr  187    80  27.0        e
# 9   us  185   105  33.0        e
# 18  fr  183    88  28.0        e
# 5   tr  180    90  30.0        e
# 8   tr  177    60  22.0        k
# 7   tr  175    90  35.0        e
# 15  fr  174    70  47.0        e
# 14  us  167    62  55.0        k
# 21  fr  166    56  42.0        k
# 10  us  165    55   NaN        k
# 20  fr  164    66  32.0        k
# 13  us  162    59   NaN        k
# 12  us  160    58  39.0        k
# 19  fr  159    40  29.0        k
# 11  us  155    50  44.0        k
# 2   tr  135    34  10.0        k
# 3   tr  133    30   9.0        k
# 0   tr  130    30  10.0        e
# 4   tr  129    38  12.0        e
# 1   tr  125    36  11.0        e

# %%
#ダニー変数への変換　df_peopleの国籍列をダミー変数へ

# %%
pd.get_dummies(df_people, columns=["国籍"])
# Out:
#     男の子  kilo   yas cinsiyet  国籍_fr  国籍_tr  国籍_us
# 0   130    30  10.0        e      0      1      0
# 1   125    36  11.0        e      0      1      0
# 2   135    34  10.0        k      0      1      0
# 3   133    30   9.0        k      0      1      0
# 4   129    38  12.0        e      0      1      0
# 5   180    90  30.0        e      0      1      0
# 6   190    80  25.0        e      0      1      0
# 7   175    90  35.0        e      0      1      0
# 8   177    60  22.0        k      0      1      0
# 9   185   105  33.0        e      0      0      1
# 10  165    55   NaN        k      0      0      1
# 11  155    50  44.0        k      0      0      1
# 12  160    58  39.0        k      0      0      1
# 13  162    59   NaN        k      0      0      1
# 14  167    62  55.0        k      0      0      1
# 15  174    70  47.0        e      1      0      0
# 16  193    90  23.0        e      1      0      0
# 17  187    80  27.0        e      1      0      0
# ...

# %%
#dfの欠損値を確認する

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.isnull() #欠損値無いんかい
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0      False    False     False        False     False        False
# 1      False    False     False        False     False        False
# 2      False    False     False        False     False        False
# 3      False    False     False        False     False        False
# 4      False    False     False        False     False        False
# ..       ...      ...       ...          ...       ...          ...
# 361    False    False     False        False     False        False
# 362    False    False     False        False     False        False
# 363    False    False     False        False     False        False
# 364    False    False     False        False     False        False
# 365    False    False     False        False     False        False
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
#欠損値の補完

# %%
df.fillna(0) #欠損値ないからどこも補完していない
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.dropna(axis=1) #欠損値がないからどこも消えてないけどな
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  WindSpeed3pm  Humidity9am  \
# 0        8.0     24.3       0.0          3.4            20           68
# 1       14.0     26.9       3.6          4.4            17           80
# 2       13.7     23.4       3.6          5.8             6           82
# 3       13.3     15.5      39.8          7.2            24           62
# 4        7.6     16.1       2.8          5.6            28           68
# ..       ...      ...       ...          ...           ...          ...
# 361      9.0     30.7       0.0          7.6            50           38
# 362      7.1     28.4       0.0         11.6            19           45
# 363     12.5     19.9       0.0          8.4             9           63
# 364     12.5     26.9       0.0          5.0            28           69
# 365     12.3     30.2       0.0          6.0            35           43
#
#      Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
#ユニークな値と出現回数 iris.csvより

# %%
df_iris = pd.read_csv("iris.csv")
df_iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Speciesを確認しようじゃないか
df_iris["Species"].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
#各クラスごとの集計
#Iris-virginica,Iris-setosa,Iris-versicolorそれぞれの
#SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCmの平均値

# %%
df_iris.groupby("Species").mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
#統計量の算出

# %%
#df_irisの各カラムごとの平均値、中央値、最大値、最小値、標準偏差を算出
df_iris.mean()
df_iris.median()
df_iris.max()
df_iris.min()
df_iris.std()
# Out:
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64

# %%
df_iris.describe() #最強
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#相関係数の算出

# %%
#MinTempとEvaporation
df[["MinTemp", "Evaporation"]].corr()
# Out:
#              MinTemp  Evaporation
# MinTemp      1.00000      0.64993
# Evaporation  0.64993      1.00000

# %%
df.corr() #全部に対して表示！
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.752471  0.201939     0.649930  0.035711
# MaxTemp        0.752471  1.000000 -0.073560     0.690026  0.452064
# Rainfall       0.201939 -0.073560  1.000000    -0.007293 -0.150990
# Evaporation    0.649930  0.690026 -0.007293     1.000000  0.318025
# Sunshine       0.035711  0.452064 -0.150990     0.318025  1.000000
# WindGustSpeed  0.218020  0.109672  0.096190     0.288477  0.095843
# WindSpeed9am   0.127542 -0.216814  0.219637     0.068929 -0.064522
# WindSpeed3pm  -0.065922 -0.167873  0.056008     0.048601  0.072573
# Humidity9am   -0.207897 -0.359602  0.150109    -0.519587 -0.499017
# Humidity3pm   -0.040709 -0.533327  0.289013    -0.391780 -0.759429
# Pressure9am   -0.501707 -0.290883 -0.331581    -0.381906  0.006276
# Pressure3pm   -0.498007 -0.379394 -0.250218    -0.391093 -0.036201
# Cloud9am       0.215776 -0.175730  0.180046    -0.106007 -0.681092
# ...
