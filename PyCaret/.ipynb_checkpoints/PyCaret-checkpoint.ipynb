# %%
#機械学習まじでこれだけでええんちゃうか、PyCaret

# %%
import pycaret

# %%
import pandas as pd
df = pd.read_csv("Boston-house-price-data.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\TAISEI\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
from pycaret.regression import *

# %%
exp = setup(df, target="MEDV")
# Out:
# <style type="text/css">
# #T_b662d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b662d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b662d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b662d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b662d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b662d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b662d_row0_col1" class="data row0 col1" >4951</td>
#     </tr>
#     <tr>
#       <th id="T_b662d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b662d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b662d_row1_col1" class="data row1 col1" >MEDV</td>
#     </tr>
#     <tr>
#       <th id="T_b662d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_c7da0 th {
#   text-align: left;
# }
# ...

# %%
model = create_model("gbr")
# Out:
# <style type="text/css">
# #T_78662_row10_col0, #T_78662_row10_col1, #T_78662_row10_col2, #T_78662_row10_col3, #T_78662_row10_col4, #T_78662_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_78662">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78662_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_78662_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_78662_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_78662_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_78662_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_78662_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(model)
# Out:
# GradientBoostingRegressor(random_state=4951)

# %%
tuned_model = tune_model(model)
# Out:
# <style type="text/css">
# #T_5bbe3_row10_col0, #T_5bbe3_row10_col1, #T_5bbe3_row10_col2, #T_5bbe3_row10_col3, #T_5bbe3_row10_col4, #T_5bbe3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5bbe3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bbe3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5bbe3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5bbe3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5bbe3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5bbe3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5bbe3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
#これはえぐい。scikit-learn要らんやん。
